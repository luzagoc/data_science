# %% [markdown]
# <a href="https://colab.research.google.com/github/luzagoc/data_science/blob/main/Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
#desabilitar avisos padrões do python
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
iris = datasets.load_iris()
clust1 = scale(iris.data)
#gerar matriz aleatória de 150 linhas e 4 colunas
clust2 = scale(np.random.rand(150,4))

# %%
inertia = []
for i in range(1,8):
  #cria o numero de cluster de acordo com o laço (=i)
  kmeans = KMeans(n_clusters=i, n_init='auto')
  kmeans.fit(clust1)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title('Elbow')
plt.show()

# %%
inertia = []
for i in range(1,8):
  #cria o numero de cluster de acordo com o laço (=i)
  kmeans = KMeans(n_clusters=i, n_init='auto')
  kmeans.fit(clust2)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title('Elbow')
plt.show()

# %%
#HOPKINS
#proximo de 0, tendencia de agrupamentos
#proximo de 1, dados aleatoriamente distribuidos
#intermediário significa que não existe uma estrutura clara

# %%
hopkins(clust1,150)
# Out:
# 0.18208478579007054

# %%
hopkins(clust2,150)
# Out:
# 0.4835780021205079

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
m = assess_tendency_by_metric(clust1, 'silhouette',5)
print(m)
# Out:
# (2, array([0.58175005, 0.46304204, 0.41889234, 0.36471772]))

# %%
m = assess_tendency_by_metric(clust1, 'davies_bouldin',5)
print(m)
# Out:
# (2, array([0.59331269, 0.83241621, 0.90706108, 0.85219326]))

# %%
m = assess_tendency_by_metric(clust1,'calinski_harabasz',5)
print(m)
# Out:
# (2, array([251.34933946, 241.31556059, 205.11953078, 168.94958568]))

# %%
m = assess_tendency_by_metric(clust2, 'silhouette',5)
print(m)
# Out:
# (5, array([0.19297446, 0.20573918, 0.1958428 , 0.22392816]))

# %%
m = assess_tendency_by_metric(clust2, 'davies_bouldin',5)
print(m)
# Out:
# (5, array([1.92381427, 1.58474211, 1.46261185, 1.31531753]))

# %%
m = assess_tendency_by_metric(clust2,'calinski_harabasz',5)
print(m)
# Out:
# (5, array([36.9068393 , 35.22426832, 31.72398943, 37.51414338]))

# %%
#média
m = assess_tendency_by_mean_metric_score(clust1,5)
print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2,5)
print(m)
# Out:
# 3.3333333333333335
